# %%
from Grid import Grid
from Cell import Cell
import numpy as np
import matplotlib.pyplot as plt
from Patterns import Pattern, AVAILABLE_PATTERNS
from utils import compute_entropy

# %%
grid = Grid(length=128, width=128, seed=42, pattern="test")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 grid = Grid(length=128, width=128, seed=42, pattern="test")
#
# File ~/Documents/PERSO/life/Grid.py:14, in Grid.__init__(self, length, width, seed, pattern)
#      12 self.seed = seed
#      13 np.random.seed(self.seed)
# ---> 14 self.__initialize_grid(pattern)
#
# File ~/Documents/PERSO/life/Grid.py:25, in Grid.__initialize_grid(self, pattern)
#      23     self.grid = random_grid(self.length, self.width)
#      24 else:
# ---> 25     raise ValueError("Invalid pattern specified. Must be a Pattern instance or a valid pattern name. List of available patterns: " + ", ".join(AVAILABLE_PATTERNS.keys()))
#
# ValueError: Invalid pattern specified. Must be a Pattern instance or a valid pattern name. List of available patterns: block, blinker, pulsar, glider, glider_gun

# %%
entropy_evolution = []

# %%
from IPython.display import clear_output
fig, ax = plt.subplots(figsize=(4, 4))

for _ in range(200):
    grid.update_grid()
    entropy_evolution.append(compute_entropy(grid))
    clear_output(wait=True)
    ax.clear()
    ax.imshow(grid.get_grid(), cmap='binary')
    ax.set_title(f'Game of Life')
    plt.pause(1e-5)
    display(fig)

# %%
plt.figure()
plt.plot(entropy_evolution)
# plot mean entropy line of the last 100 generations
mean_entropy = np.mean(entropy_evolution[-200:])
plt.axhline(y=mean_entropy, color='r', linestyle='--', label='Mean Entropy (last 200 gens)')
plt.legend()
plt.title('Entropy Evolution')
plt.xlabel('Generation')
plt.ylabel('Entropy')
plt.show()
